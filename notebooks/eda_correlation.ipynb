# %%
import numpy as np
import xarray as xr
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_parquet("../dataset/combined/undersampled/train-sel-10.parquet")
df
# Out:
#        zone_id   sob_mean     sob_sum   fe_mean    fe_sum      so_sum  \
# 58033      710  35.657410  570.518555  0.003417  0.006834  570.024780
# 4352      7238  34.724483  416.693787  0.000024  0.000047  421.812561
# 31168     2339  34.973125  419.677490  0.000378  0.000378  420.768982
# 65219      888  34.678394  381.462341  0.001497  0.001497  380.636230
# 1136      1991  34.941536  314.473816  0.000074  0.000074  318.272919
# ...        ...        ...         ...       ...       ...         ...
# 28826      343  34.835129  557.362061  0.001184  0.001184  565.138794
# 67023     2374  35.182350  387.005859  0.004624  0.009248  386.982849
# 1489      5474  34.733833  416.806000  0.000050  0.000101  419.629761
# 18548     1732  35.105625  386.161896  0.000698  0.000698  383.574402
# 35241     3388  34.530685  552.490967  0.002108  0.004215  550.222778
#
#        po4_mean     pbo_mean       pbo_sum   tob_mean     tob_sum  target
# ...

# %%
df_corr = df.drop(columns=["zone_id"]).corr()
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))

plt.figure(figsize=(10, 6))
sns.heatmap(df_corr, annot=True, cmap="vlag", mask=mask)
# Out:
# <Axes: >
